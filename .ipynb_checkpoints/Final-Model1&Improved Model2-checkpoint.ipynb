# %%
import matplotlib.pyplot as plt
import zipfile as zf
import numpy as np
import os
import PIL
import tensorflow as tf
import random


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.callbacks import ModelCheckpoint,EarlyStopping

from keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout,SpatialDropout2D

# %%
files = zf.ZipFile("dataset-resized.zip",'r')
files.extractall()
files.close()

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['.DS_Store', 'cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
import pathlib
data_dir= pathlib.Path(os.getcwd())/"dataset-resized"
data_dir
# Out:
# WindowsPath('C:/Users/lelo/Waste/dataset-resized')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 2527

# %%
metal = list(data_dir.glob('metal/*'))
PIL.Image.open(str(metal[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF4F623A00>

# %%
glass = list(data_dir.glob('glass/*'))
PIL.Image.open(str(glass[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF4F6CEE50>

# %%
paper = list(data_dir.glob('paper/*'))
PIL.Image.open(str(paper[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF4F623550>

# %%
cardboard = list(data_dir.glob('cardboard/*'))
PIL.Image.open(str(cardboard[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF4F66C670>

# %%
plastic = list(data_dir.glob('plastic/*'))
PIL.Image.open(str(plastic[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF455FF370>

# %%
trash = list(data_dir.glob('trash/*'))
PIL.Image.open(str(trash[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x1CF4F66CFA0>

# %%
batch_size = 32 
img_height = 300
img_width = 300

# %%
  train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 300, 300, 3)
# (32,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 300, 300, 3)
# (32,)

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.12170029 0.97360086

# %%
num_classes = len(class_names)

model = Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 300, 300, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11214976
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 11,239,334
# Trainable params: 11,239,334
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
#  1/64 [..............................] - ETA: 0s - loss: 1.8061 - acc: 0.0625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0170s vs `on_train_batch_end` time: 0.0279s). Check your callbacks.
# 64/64 [==============================] - 8s 128ms/step - loss: 1.5711 - acc: 0.3680 - val_loss: 1.4044 - val_acc: 0.4950
# Epoch 2/10
# 64/64 [==============================] - 3s 50ms/step - loss: 1.2097 - acc: 0.5401 - val_loss: 1.2021 - val_acc: 0.5129
# Epoch 3/10
# 64/64 [==============================] - 3s 50ms/step - loss: 0.9912 - acc: 0.6217 - val_loss: 1.0233 - val_acc: 0.6079
# Epoch 4/10
# 64/64 [==============================] - 3s 50ms/step - loss: 0.8547 - acc: 0.6860 - val_loss: 1.2324 - val_acc: 0.5129
# Epoch 5/10
# 64/64 [==============================] - 3s 50ms/step - loss: 0.6718 - acc: 0.7666 - val_loss: 1.1534 - val_acc: 0.6257
# Epoch 6/10
# 64/64 [==============================] - 3s 50ms/step - loss: 0.4433 - acc: 0.8487 - val_loss: 1.2290 - val_acc: 0.5960
# Epoch 7/10
# 64/64 [==============================] - 3s 51ms/step - loss: 0.3017 - acc: 0.9125 - val_loss: 1.3875 - val_acc: 0.6416
# Epoch 8/10
# 64/64 [==============================] - 3s 51ms/step - loss: 0.2200 - acc: 0.9298 - val_loss: 1.5392 - val_acc: 0.6020
# Epoch 9/10
# 64/64 [==============================] - 3s 51ms/step - loss: 0.1518 - acc: 0.9510 - val_loss: 1.6501 - val_acc: 0.6000
# Epoch 10/10
# 64/64 [==============================] - 3s 50ms/step - loss: 0.1078 - acc: 0.9659 - val_loss: 1.8182 - val_acc: 0.6079 - loss: 0.0729 - acc: - ETA: 0s - loss: 0.0956 - acc:

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
train_datagen = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.1,
    rescale=1./255,
    shear_range = 0.1,
    zoom_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1,)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.1)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(300, 300),
    batch_size=32,
    class_mode='categorical',
    subset='training')

validation_generator = test_datagen.flow_from_directory(
    data_dir,
    target_size=(300, 300),
    batch_size=32,
    class_mode='categorical',
    subset='validation')

labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

print(labels)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
model2=Sequential()
#Convolution blocks

model2.add(Conv2D(32,(3,3), padding='same',input_shape=(300,300,3),activation='relu'))
model2.add(MaxPooling2D(pool_size=2)) 
#model.add(SpatialDropout2D(0.5)) # No accuracy

model2.add(Conv2D(64,(3,3), padding='same',activation='relu'))
model2.add(MaxPooling2D(pool_size=2)) 
#model.add(SpatialDropout2D(0.5))

model2.add(Conv2D(32,(3,3), padding='same',activation='relu'))
model2.add(MaxPooling2D(pool_size=2)) 

#Classification layers
model2.add(Flatten())

model2.add(Dense(64,activation='relu'))
#model.add(SpatialDropout2D(0.5))
model2.add(Dropout(0.2))
model2.add(Dense(32,activation='relu'))

model2.add(Dropout(0.2))
model2.add(Dense(6,activation='softmax'))

filepath="trained_model.h5"
checkpoint1 = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint1]

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 43808)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                2803776
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 2,843,910
# Trainable params: 2,843,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
history = model2.fit_generator(train_generator,
                              epochs=100,
                              steps_per_epoch=2276//32,
                              validation_data=validation_generator,
                              validation_steps=251//32,
                              workers = 4,
                              callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From C:\Users\lelo\AppData\Local\Temp/ipykernel_19212/2435000133.py:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 71/71 [==============================] - ETA: 0s - loss: 1.7169 - acc: 0.2678
# Epoch 00001: val_acc improved from -inf to 0.27679, saving model to trained_model.h5
# 71/71 [==============================] - 14s 203ms/step - loss: 1.7169 - acc: 0.2678 - val_loss: 1.6493 - val_acc: 0.2768
# Epoch 2/100
# 71/71 [==============================] - ETA: 0s - loss: 1.5284 - acc: 0.3578
# Epoch 00002: val_acc improved from 0.27679 to 0.39732, saving model to trained_model.h5
# 71/71 [==============================] - 14s 202ms/step - loss: 1.5284 - acc: 0.3578 - val_loss: 1.4452 - val_acc: 0.3973
# Epoch 3/100
# 71/71 [==============================] - ETA: 0s - loss: 1.4403 - acc: 0.4064
# Epoch 00003: val_acc improved from 0.39732 to 0.46875, saving model to trained_model.h5
# 71/71 [==============================] - 14s 194ms/step - loss: 1.4403 - acc: 0.4064 - val_loss: 1.3117 - val_acc: 0.4688
# Epoch 4/100
# 71/71 [==============================] - ETA: 0s - loss: 1.3238 - acc: 0.4777
# Epoch 00004: val_acc improved from 0.46875 to 0.52679, saving model to trained_model.h5
# 71/71 [==============================] - 14s 194ms/step - loss: 1.3238 - acc: 0.4777 - val_loss: 1.2961 - val_acc: 0.5268
# Epoch 5/100
# 71/71 [==============================] - ETA: 0s - loss: 1.2815 - acc: 0.4933
# Epoch 00005: val_acc did not improve from 0.52679
# 71/71 [==============================] - 14s 195ms/step - loss: 1.2815 - acc: 0.4933 - val_loss: 1.3132 - val_acc: 0.4866
# Epoch 6/100
# 71/71 [==============================] - ETA: 0s - loss: 1.2949 - acc: 0.4973
# Epoch 00006: val_acc did not improve from 0.52679
# 71/71 [==============================] - 15s 205ms/step - loss: 1.2949 - acc: 0.4973 - val_loss: 1.2539 - val_acc: 0.5134
# Epoch 7/100
# 71/71 [==============================] - ETA: 0s - loss: 1.2507 - acc: 0.5165
# Epoch 00007: val_acc did not improve from 0.52679
# 71/71 [==============================] - 15s 208ms/step - loss: 1.2507 - acc: 0.5165 - val_loss: 1.3619 - val_acc: 0.4598
# Epoch 8/100
# 71/71 [==============================] - ETA: 0s - loss: 1.2060 - acc: 0.5401
# Epoch 00008: val_acc improved from 0.52679 to 0.58036, saving model to trained_model.h5
# 71/71 [==============================] - 15s 210ms/step - loss: 1.2060 - acc: 0.5401 - val_loss: 1.1668 - val_acc: 0.5804
# Epoch 9/100
# 71/71 [==============================] - ETA: 0s - loss: 1.1620 - acc: 0.5731- ETA: 3s - loss: 1.
# Epoch 00009: val_acc did not improve from 0.58036
# 71/71 [==============================] - 14s 202ms/step - loss: 1.1620 - acc: 0.5731 - val_loss: 1.2035 - val_acc: 0.5134
# Epoch 10/100
# 71/71 [==============================] - ETA: 0s - loss: 1.1564 - acc: 0.5695
# Epoch 00010: val_acc did not improve from 0.58036
# 71/71 [==============================] - 14s 191ms/step - loss: 1.1564 - acc: 0.5695 - val_loss: 1.1284 - val_acc: 0.5625
# Epoch 11/100
# 71/71 [==============================] - ETA: 0s - loss: 1.1196 - acc: 0.5784
# Epoch 00011: val_acc did not improve from 0.58036
# 71/71 [==============================] - 14s 195ms/step - loss: 1.1196 - acc: 0.5784 - val_loss: 1.2564 - val_acc: 0.5312
# Epoch 12/100
# 71/71 [==============================] - ETA: 0s - loss: 1.1006 - acc: 0.5619
# Epoch 00012: val_acc did not improve from 0.58036
# 71/71 [==============================] - 13s 189ms/step - loss: 1.1006 - acc: 0.5619 - val_loss: 1.2096 - val_acc: 0.5759
# Epoch 13/100
# 71/71 [==============================] - ETA: 0s - loss: 1.0291 - acc: 0.6127
# Epoch 00013: val_acc improved from 0.58036 to 0.62054, saving model to trained_model.h5
# 71/71 [==============================] - 13s 190ms/step - loss: 1.0291 - acc: 0.6127 - val_loss: 1.0632 - val_acc: 0.6205
# Epoch 14/100
# 71/71 [==============================] - ETA: 0s - loss: 1.0652 - acc: 0.5998
# Epoch 00014: val_acc did not improve from 0.62054
# 71/71 [==============================] - 13s 189ms/step - loss: 1.0652 - acc: 0.5998 - val_loss: 1.1596 - val_acc: 0.5670
# Epoch 15/100
# 71/71 [==============================] - ETA: 0s - loss: 1.0245 - acc: 0.6341
# Epoch 00015: val_acc improved from 0.62054 to 0.62500, saving model to trained_model.h5
# 71/71 [==============================] - 13s 190ms/step - loss: 1.0245 - acc: 0.6341 - val_loss: 1.0007 - val_acc: 0.6250
# Epoch 16/100
# 71/71 [==============================] - ETA: 0s - loss: 0.9873 - acc: 0.6453- ETA: 1s - loss: 0.9740 -
# Epoch 00016: val_acc improved from 0.62500 to 0.62946, saving model to trained_model.h5
# 71/71 [==============================] - 14s 190ms/step - loss: 0.9873 - acc: 0.6453 - val_loss: 0.9827 - val_acc: 0.6295
# Epoch 17/100
# 71/71 [==============================] - ETA: 0s - loss: 1.0080 - acc: 0.6194- ETA: 3s - loss
# Epoch 00017: val_acc improved from 0.62946 to 0.64732, saving model to trained_model.h5
# 71/71 [==============================] - 13s 190ms/step - loss: 1.0080 - acc: 0.6194 - val_loss: 1.0303 - val_acc: 0.6473
# Epoch 18/100
# 71/71 [==============================] - ETA: 0s - loss: 0.9637 - acc: 0.6506
# Epoch 00018: val_acc improved from 0.64732 to 0.65179, saving model to trained_model.h5
# 71/71 [==============================] - 14s 192ms/step - loss: 0.9637 - acc: 0.6506 - val_loss: 0.9387 - val_acc: 0.6518
# Epoch 19/100
# 71/71 [==============================] - ETA: 0s - loss: 0.
val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 186ms/step - loss: 0.4725 - acc: 0.8298 - val_loss: 0.7635 - val_acc: 0.7545
# Epoch 90/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4731 - acc: 0.8244
# Epoch 00090: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 186ms/step - loss: 0.4731 - acc: 0.8244 - val_loss: 0.7380 - val_acc: 0.7679
# Epoch 91/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4972 - acc: 0.8272
# Epoch 00091: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 186ms/step - loss: 0.4965 - acc: 0.8275 - val_loss: 0.7063 - val_acc: 0.7812
# Epoch 92/100
# 71/71 [==============================] - ETA: 0s - loss: 0.5072 - acc: 0.8142
# Epoch 00092: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 186ms/step - loss: 0.5072 - acc: 0.8142 - val_loss: 0.7049 - val_acc: 0.7768
# Epoch 93/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4547 - acc: 0.8431
# Epoch 00093: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 184ms/step - loss: 0.4547 - acc: 0.8431 - val_loss: 0.7525 - val_acc: 0.7589
# Epoch 94/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4441 - acc: 0.8498
# Epoch 00094: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 187ms/step - loss: 0.4441 - acc: 0.8498 - val_loss: 0.6776 - val_acc: 0.7768
# Epoch 95/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4380 - acc: 0.8422
# Epoch 00095: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 184ms/step - loss: 0.4380 - acc: 0.8422 - val_loss: 0.6739 - val_acc: 0.7812
# Epoch 96/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4916 - acc: 0.8191
# Epoch 00096: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 186ms/step - loss: 0.4916 - acc: 0.8191 - val_loss: 0.6754 - val_acc: 0.7634
# Epoch 97/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4340 - acc: 0.8454- ETA: 3s - loss: 0
# Epoch 00097: val_acc did not improve from 0.79018
# 71/71 [==============================] - 14s 194ms/step - loss: 0.4340 - acc: 0.8454 - val_loss: 0.6933 - val_acc: 0.7768
# Epoch 98/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4263 - acc: 0.8467
# Epoch 00098: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 187ms/step - loss: 0.4263 - acc: 0.8467 - val_loss: 0.6897 - val_acc: 0.7589
# Epoch 99/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4772 - acc: 0.8333- ETA:
# Epoch 00099: val_acc did not improve from 0.79018
# 71/71 [==============================] - 13s 187ms/step - loss: 0.4772 - acc: 0.8333 - val_loss: 0.6816 - val_acc: 0.7455
# Epoch 100/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4645 - acc: 0.8356- ETA: 0s - loss: 0.4637 - acc: 0.835
# Epoch 00100: val_acc improved from 0.79018 to 0.80804, saving model to trained_model.h5
# 71/71 [==============================] - 13s 185ms/step - loss: 0.4645 - acc: 0.8356 - val_loss: 0.6113 - val_acc: 0.8080

# %%
 acc = history.history['acc']
val_acc =history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']



plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
test_x, test_y = validation_generator.__getitem__(1)

preds = model2.predict(test_x)

plt.figure(figsize=(16, 16))
for i in range(16):
    plt.subplot(4, 4, i+1) 
    plt.title('pred:%s / truth:%s' % (labels[np.argmax(preds[i])], labels[np.argmax(test_y[i])]))
    plt.imshow(test_x[i])

# %%
predicted= []
actual = []
for i in range(21):
    predicted.append(labels[np.argmax(preds[i])])
    actual.append(labels[np.argmax(test_y[i])])

import pandas as pd
df = pd.DataFrame(predicted, columns=["predicted"])
df["actual"]  = actual
df
# Out:
#     predicted     actual
# 0       paper      paper
# 1     plastic    plastic
# 2       metal    plastic
# 3     plastic    plastic
# 4       paper      metal
# 5     plastic    plastic
# 6     plastic    plastic
# 7   cardboard  cardboard
# 8   cardboard  cardboard
# 9       glass      glass
# 10      glass      glass
# 11  cardboard  cardboard
# 12      paper      paper
# 13      glass      glass
# 14      paper      paper
# 15      paper      paper
# 16      paper      paper
# 17      trash      trash
# 18      trash  cardboard
# 19      paper      paper
# 20      metal      metal
